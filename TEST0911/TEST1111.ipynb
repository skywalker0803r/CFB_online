# %% [markdown]
# ## 載入所需套件

# %%
from crawl_pi_server import get_summary_values,async_get_values,get_tag_snapshot
#from crawl_pi_server import async_get_summary_webapi
import datetime
import pandas as pd
import seaborn as sns
import numpy as np
# Out:
# Name=10.110.108.220, Host=10.110.108.220, Port=5450, ConnectionTimeOut=00:00:10 OperationTimeOut=00:01:00
# PI_SERVER: 10.110.108.220

# %% [markdown]
# ## 點位名稱

# %%
tag1 = {
 # CFB Boiler
 'MLUT4_AIA791101A':'ECO O2_A #1',
 'MLUT4_AIA791101B':'ECO O2_B #1',
 'MLUT4_AIC-132B': 'ECO SOx #1',
 'MLUT4_AT-132A': 'ECO NOx #1',
 'MLUT4_AT-137': '煙囪O2_#1',
 'MLUT4_AT-140': '煙囪SOx #1',
 'MLUT4_FIC-131A': '飼料機A#1',  #*#
 'MLUT4_FIC-131B': '飼料機B#1',  #*#
 'MLUT4_FIC-131C': '飼料機C#1',  #*#
 'MLUT4_FIC-133': 'GAH出口SA流量#1',
 'MLUT4_FIQ-1BTCF': '總飼煤量#1',  #*#
 'MLUT4_FQ-105': '主蒸汽#1',  #*#
 'MLUT4_FQ-139': '煙氣流量#1',
 'MLUT4_FT-132': 'GAH出口PA流量#1',
 'MLUT4_FT-791011': '廢氣流量#1',  #*#
 'MLUT4_FT-791020': '廢水VOC#1',  #*#
 'MLUT4_FT-V003': 'SRF用量#1',
 'MLUT4_IT-E7915A': '底灰機電流A#1',
 'MLUT4_IT-E7915B': '底灰機電流B#1',
 'MLUT4_PDIC-133': '整層壓差#1',
 'MLUT4_PDT-131': '下層壓差#1',  #*#
 'MLUT4_PDT-132': '上層壓差#1',
 'MLUT4_PIC-133': 'GAH出口SA壓力#1',
 'MLUT4_PT-131': 'GAH出口PA壓力#1',
 'MLUT4_RQ-1BTLS': '石灰石#1',  #*#
 'MLUT4_RT-79011A': '20T石灰石A#1',  #*#
 'MLUT4_RT-79011B': '20T石灰石B#1',  #*#
 'MLUT4_RT-79011C': '20T石灰石C#1',  #*#
 'MLUT4_RT-79012A': '10T石灰石A#1',  #*#
 'MLUT4_RT-79012B': '10T石灰石B#1',  #*#
 'MLUT4_IT-79011A': '20T石灰石鼓風機運轉電流A#1',
 'MLUT4_IT-79011B': '20T石灰石鼓風機運轉電流B#1',
 'MLUT4_IT-79011C': '20T石灰石鼓風機運轉電流C#1',
 'MLUT4_IT-79011D': '20T石灰石鼓風機運轉電流D#1',
 'MLUT4_IT-79012A': '10T石灰石鼓風機運轉電流A#1',
 'MLUT4_IT-79012B': '10T石灰石鼓風機運轉電流B#1',
 'MLUT4_IT-79012C': '10T石灰石鼓風機運轉電流C#1',
 'MLUT4_TE-151A': '下層爐溫A#1',
 'MLUT4_TE-151B': '下層爐溫B#1',
 'MLUT4_TE-151C': '下層爐溫C#1',  #*#
 'MLUT4_TE-151D': '下層爐溫D#1',  #*#
 'MLUT4_TE-151E': '下層爐溫E#1',
 'MLUT4_TE-151F': '下層爐溫F#1',
 'MLUT4_TE-151G': '下層爐溫G#1',
 'MLUT4_TE-151H': '下層爐溫H#1',  #*#
 'MLUT4_TE-151I': '下層爐溫I#1',
'MLUT4_TE-151AVG': '下層平均爐溫#1',   #**#
 'MLUT4_TE-152A': '上層爐溫A#1',
 'MLUT4_TE-152B': '上層爐溫B#1',
 'MLUT4_TE-152C': '上層爐溫C#1',  #*#
 'MLUT4_TE-152D': '上層爐溫D#1',  #*#
 'MLUT4_TE-152E': '上層爐溫E#1',
 'MLUT4_TE-152F': '上層爐溫F#1',
 'MLUT4_TE-152G': '上層爐溫G#1',
 'MLUT4_TE-152H': '上層爐溫H#1',  #*#
 'MLUT4_TE-152I': '上層爐溫I#1',
 'MLUT4_TE-152AVG': '上層平均爐溫#1',   #**#
 'MLUT4_ZT-131': 'PAF風門開度#1',
 'MLUT4_ZT-132': 'SAF風門開度#1',
 'MLUT4_TE-136A': 'GAH出口溫度A#1',
 'MLUT4_TE-136B': 'GAH出口溫度B#1',
 'MLUT4_TE-136C': 'GAH出口溫度C#1',
 'MLUT4_TE-153A': 'Cyclone入口溫度東側A#1',
 'MLUT4_TE-153B': 'Cyclone入口溫度東側B#1',
 'MLUT4_TE-154A': 'Cyclone入口溫度西側A#1',
 'MLUT4_TE-154B': 'Cyclone入口溫度西側B#1',
 'MLUT4_TE-155A': 'Cyclone出口溫度東側A#1',
 'MLUT4_TE-155B': 'Cyclone出口溫度東側B#1',
 'MLUT4_TE-156A': 'Cyclone出口溫度西側A#1',
 'MLUT4_TE-156B': 'Cyclone出口溫度西側B#1',
 # NID parameter
 'MLUT4_FT-853':'NID 10線灰再循環量#1',  #*#
 'MLUT4_FT-854':'NID 20線灰再循環量#1',  #*#
 'MLUT4_RT-853':'NID 10線旋轉閥轉速#1',  #*#
 'MLUT4_RT-854':'NID 20線旋轉閥轉速#1',  #*#
 'MLUT4_PDT-853A':'NID 10線U型反應區壓差A#1',
 'MLUT4_PDT-853B':'NID 10線U型反應區壓差B#1',
 'MLUT4_PDT-857A':'NID 20線U型反應區壓差A#1',
 'MLUT4_PDT-857B':'NID 20線U型反應區壓差B#1',
 'MLUT4_PDT-856':'NID 10線濾袋壓差#1',
 'MLUT4_PDT-857':'NID 20線濾袋壓差#1',
 'MLUT4_FT-851AA': 'NID_10線燃氣流量A#1',
 'MLUT4_FT-851AB': 'NID_10線燃氣流量B#1',
 'MLUT4_FT-851BA': 'NID_20線燃氣流量A#1',
 'MLUT4_FT-851BB': 'NID_20線燃氣流量B#1',
 'MLUT4_TE-851A': 'NID_10線入口溫度#1',
 'MLUT4_TE-851B': 'NID_20線入口溫度#1',
 'MLUT4_TE-853A': 'NID_10線出口溫度A#1',
 'MLUT4_TE-853B': 'NID_10線出口溫度B#1',
 'MLUT4_TE-854A': 'NID_20線出口溫度A#1',
 'MLUT4_TE-854B': 'NID_20線出口溫度B#1',
 'MLUT4_FT-856': 'NID注水量_10線#1',  #*#
 'MLUT4_FT-857': 'NID注水量_20線#1',  #*#
 'MLUT4_TE-851A':'NID入口溫度A#1',  #*#
 'MLUT4_TE-851B':'NID入口溫度B#1',  #*#
 'MLUT4_TE-853A':'NID10線出口溫度A#1',  #*#
 'MLUT4_TE-853B':'NID10線出口溫度B#1',  #*#
 'MLUT4_TE-854A':'NID20線出口溫度A#1',  #*#
 'MLUT4_TE-854B':'NID20線出口溫度B#1',  #*#
 'MLUT4_IT-B7916A':'NID流體化鼓風機電流A#1',
 'MLUT4_IT-B7916B':'NID流體化鼓風機電流B#1',
 'MLUT4_IT-B7916C':'NID流體化鼓風機電流C#1',
  # 新增
 'MLUT4_LT-071A':'750T 石灰石儲槽液位',
}

tag2 = {
# CFB Boiler
 'MLUT4_AIA792101A':'ECO O2_A #2',
 'MLUT4_AIA792101B':'ECO O2_B #2',
 'MLUT4_AIC-232B': 'ECO SOx #2',
 'MLUT4_AT-232A': 'ECO NOx #2',
 'MLUT4_AT-237': '煙囪O2_#2',
 'MLUT4_AT-240': '煙囪SOx #2',
 'MLUT4_FIC-231A': '飼料機A#2',
 'MLUT4_FIC-231B': '飼料機B#2',
 'MLUT4_FIC-231C': '飼料機C#2',
 'MLUT4_FIC-233': 'GAH出口SA流量#2',
 'MLUT4_FIQ-2BTCF': '總飼煤量#2',
 'MLUT4_FQ-205': '主蒸汽#2',
 'MLUT4_FQ-239': '煙氣流量#2',
 'MLUT4_FT-232': 'GAH出口PA流量#2',
 'MLUT4_FT-792003': '廢氣流量#2',
 'MLUT4_FT-792020': '廢水VOC#2',
 'MLUT4_FT-V004': 'SRF用量#2',
 'MLUT4_IT-E7925A': '底灰機電流A#2',
 'MLUT4_IT-E7925B': '底灰機電流B#2',
 'MLUT4_PDIC-233': '整層壓差#2',
 'MLUT4_PDT-231': '下層壓差#2',
 'MLUT4_PDT-232': '上層壓差#2',
 'MLUT4_PIC-233': 'GAH出口SA壓力#2',
 'MLUT4_PT-231': 'GAH出口PA壓力#2',
 'MLUT4_RQ-2BTLS': '石灰石#2',
 'MLUT4_RT-031': '20T石灰石A#2',
 'MLUT4_RT-041': '20T石灰石B#2',
 'MLUT4_RT-051': '20T石灰石C#2',
 'MLUT4_RT-081': '10T石灰石A#2',
 'MLUT4_RT-091': '10T石灰石B#2',
 'MLUT4_IT-79021A': '20T石灰石鼓風機運轉電流A#2',
 'MLUT4_IT-79021B': '20T石灰石鼓風機運轉電流B#2',
 'MLUT4_IT-79021C': '20T石灰石鼓風機運轉電流C#2',
 'MLUT4_IT-79021D': '20T石灰石鼓風機運轉電流D#2',
 'MLUT4_IT-79022A': '10T石灰石鼓風機運轉電流A#2',
 'MLUT4_IT-79022B': '10T石灰石鼓風機運轉電流B#2',
 'MLUT4_IT-79022C': '10T石灰石鼓風機運轉電流C#2',
 'MLUT4_TE-251A': '下層爐溫A#2',
 'MLUT4_TE-251B': '下層爐溫B#2',
 'MLUT4_TE-251C': '下層爐溫C#2',
 'MLUT4_TE-251D': '下層爐溫D#2',
 'MLUT4_TE-251E': '下層爐溫E#2',
 'MLUT4_TE-251F': '下層爐溫F#2',
 'MLUT4_TE-251G': '下層爐溫G#2',
 'MLUT4_TE-251H': '下層爐溫H#2',
 'MLUT4_TE-251I': '下層爐溫I#2',
'MLUT4_TE-251AVG': '下層平均爐溫#2',   #**#
 'MLUT4_TE-252A': '上層爐溫A#2',
 'MLUT4_TE-252B': '上層爐溫B#2',
 'MLUT4_TE-252C': '上層爐溫C#2',
 'MLUT4_TE-252D': '上層爐溫D#2',
 'MLUT4_TE-252E': '上層爐溫E#2',
 'MLUT4_TE-252F': '上層爐溫F#2',
 'MLUT4_TE-252G': '上層爐溫G#2',
 'MLUT4_TE-252H': '上層爐溫H#2',
 'MLUT4_TE-252I': '上層爐溫I#2',
'MLUT4_TE-252AVG': '上層平均爐溫#2',   #**#
 'MLUT4_ZT-231': 'PAF風門開度#2',
 'MLUT4_ZT-232': 'SAF風門開度#2',
 'MLUT4_SIV-B7921':'PAF變頻轉速#2', 
 'MLUT4_TE-236A': 'GAH出口溫度A#2',
 'MLUT4_TE-236B': 'GAH出口溫度B#2',
 'MLUT4_TE-236C': 'GAH出口溫度C#2',  ##
 'MLUT4_TE-253A': 'Cyclone入口溫度東側A#2',
 'MLUT4_TE-253B': 'Cyclone入口溫度東側B#2',
 'MLUT4_TE-254A': 'Cyclone入口溫度西側A#2',
 'MLUT4_TE-254B': 'Cyclone入口溫度西側B#2',
 'MLUT4_TE-255A': 'Cyclone出口溫度東側A#2',
 'MLUT4_TE-255B': 'Cyclone出口溫度東側B#2',
 'MLUT4_TE-256A': 'Cyclone出口溫度西側A#2',
 'MLUT4_TE-256B': 'Cyclone出口溫度西側B#2',
# NID parameter
 'MLUT4_FT-953':'NID 10線灰再循環量#2',
 'MLUT4_FT-954':'NID 20線灰再循環量#2',
 'MLUT4_RT-953':'NID 10線旋轉閥轉速#2',
 'MLUT4_RT-954':'NID 20線旋轉閥轉速#2',
# 'MLUT4_PDT-953A':'NID 10線U型反應區壓差A#2', ##
# 'MLUT4_PDT-953B':'NID 10線U型反應區壓差B#2', ##
# 'MLUT4_PDT-957A':'NID 20線U型反應區壓差A#2', ##
# 'MLUT4_PDT-957B':'NID 20線U型反應區壓差B#2', ##
 'MLUT4_PDT-956':'NID 10線濾袋壓差#2',
 'MLUT4_PDT-957':'NID 20線濾袋壓差#2',
 'MLUT4_FT-951AA': 'NID_10線燃氣流量A#2',
 'MLUT4_FT-951AB': 'NID_10線燃氣流量B#2',
 'MLUT4_FT-951BA': 'NID_20線燃氣流量A#2',
 'MLUT4_FT-951BB': 'NID_20線燃氣流量B#2',
 'MLUT4_TE-951A': 'NID_10線入口溫度#2',
 'MLUT4_TE-951B': 'NID_20線入口溫度#2',
 'MLUT4_TE-953A': 'NID_10線出口溫度A#2',
 'MLUT4_TE-953B': 'NID_10線出口溫度B#2',
 'MLUT4_TE-954A': 'NID_20線出口溫度A#2',
 'MLUT4_TE-954B': 'NID_20線出口溫度B#2',
 'MLUT4_FT-956': 'NID注水量_10線#2',
 'MLUT4_FT-957': 'NID注水量_20線#2',
 'MLUT4_TE-951A':'NID入口溫度A#2',
 'MLUT4_TE-951B':'NID入口溫度B#2',
 'MLUT4_TE-953A':'NID10線出口溫度A#2',
 'MLUT4_TE-953B':'NID10線出口溫度B#2',
 'MLUT4_TE-954A':'NID20線出口溫度A#2',
 'MLUT4_TE-954B':'NID20線出口溫度B#2',
 'MLUT4_IT-B7926A':'NID流體化鼓風機電流A#2',
 'MLUT4_IT-B7926B':'NID流體化鼓風機電流B#2',
 'MLUT4_IT-B7926C':'NID流體化鼓風機電流C#2',
  # 新增
 'MLUT4_LT-071A':'750T 石灰石儲槽液位',
 }

# %% [markdown]
# ## 擷取數據

# %%
from datetime import datetime, timedelta
# 計算近 50 天的時間範圍
end_time = datetime.now()  # 當前時間
start_time = end_time - timedelta(days=5)  # 50 天前

# 將時間轉換為適當的格式（取決於 async_get_values 的 API 要求）
start_time_str = start_time.strftime('%Y-%m-%d %H:%M:%S')
end_time_str = end_time.strftime('%Y-%m-%d %H:%M:%S')

# %%
#help(async_get_values)

# %%
# 獲取數據 CFB1
cfb1 = async_get_values(
    tag1.keys(),
    timestart=start_time_str,
    timeend=end_time_str,
    interval='30s'  # 30 秒間隔
)

# 後續處理（與原程式碼相同）
for c in cfb1:
    cfb1[c] = pd.to_numeric(cfb1[c], errors='coerce')

cfb1['前爐SOx濃度'] = cfb1['MLUT4_FIQ-1BTCF'] * 8 / cfb1['MLUT4_FQ-139'] * 24.5 * 1000 / 32.065
cfb1['鈣硫比'] = cfb1['MLUT4_RQ-1BTLS'] / cfb1['MLUT4_FIQ-1BTCF'] * 0.32 / 0.008
cfb1['DeSOx_1st'] = (cfb1['前爐SOx濃度'] - cfb1['MLUT4_AIC-132B']) / cfb1['前爐SOx濃度']
cfb1['DeSOx_2nd'] = (cfb1['MLUT4_AIC-132B'] - cfb1['MLUT4_AT-140']) / cfb1['MLUT4_AIC-132B']

cfb1 = cfb1[sorted(cfb1.columns)]
new_index = cfb1.index.to_list() + ['datetime']
cfb1 = pd.concat([pd.Series(tag1).to_frame().T, cfb1], axis=0, ignore_index=True)
cfb1.index = new_index
# Out:
# Progress: [██████████████████████████████████████████████████] 96/96 (100%) | Elapsed: 71.8s
# ✅ 完成查詢，耗時 0:01:14.99

# %%
cfb1.head()
# Out:
#                     MLUT4_AIA791101A MLUT4_AIA791101B MLUT4_AIC-132B  \
# 2025-11-06 15:03:01      ECO O2_A #1      ECO O2_B #1     ECO SOx #1
# 2025-11-06 15:03:31         4.039792              4.3      29.520554
# 2025-11-06 15:04:01         3.947024              4.3      29.920234
# 2025-11-06 15:04:31         3.999837         4.219982      30.349573
# 2025-11-06 15:05:01         3.966827              4.2      31.340513
#
#                     MLUT4_AT-132A MLUT4_AT-137 MLUT4_AT-140 MLUT4_FIC-131A  \
# 2025-11-06 15:03:01    ECO NOx #1      煙囪O2_#1     煙囪SOx #1         飼料機A#1
# 2025-11-06 15:03:31    185.927718     7.837133     1.080095      13.346213
# 2025-11-06 15:04:01     187.27366     7.794848     1.003544      13.346313
# 2025-11-06 15:04:31    183.120762     7.754658     0.982102      13.346413
# 2025-11-06 15:05:01    181.562125     7.714659     0.966312      13.346513
#
#                     MLUT4_FIC-131B MLUT4_FIC-131C MLUT4_FIC-133  ...  \
# 2025-11-06 15:03:01         飼料機B#1         飼料機C#1   GAH出口SA流量#1  ...
# 2025-11-06 15:03:31      10.022716       7.364468    211.219734  ...
# 2025-11-06 15:04:01      10.022466       7.365467    205.423967  ...
# 2025-11-06 15:04:31      10.022216       7.366467    197.377053  ...
# 2025-11-06 15:05:01      10.021966       7.367467    204.790473  ...
#
#                      MLUT4_FT-856  MLUT4_FT-857 MLUT4_IT-B7916A  \
# 2025-11-06 15:03:01  NID注水量_10線#1  NID注水量_20線#1  NID流體化鼓風機電流A#1
# 2025-11-06 15:03:31   3159.999416    3139.86786        91.86488
# 2025-11-06 15:04:01   3157.647067   3131.194796        91.66675
# 2025-11-06 15:04:31   3152.323999   3125.141787            92.0
# 2025-11-06 15:05:01   3157.657639   3125.936962            92.0
#
#                     MLUT4_IT-B7916B MLUT4_IT-B7916C MLUT4_LT-071A DeSOx_1st  \
# 2025-11-06 15:03:01  NID流體化鼓風機電流B#1  NID流體化鼓風機電流C#1  750T 石灰石儲槽液位       NaN
# 2025-11-06 15:03:31       89.863155             0.0     14.084942  0.937467
# 2025-11-06 15:04:01       89.001644             0.0     14.104354  0.936360
# 2025-11-06 15:04:31       89.800183             0.0     14.123766  0.935232
# 2025-11-06 15:05:01       89.199867             0.0     14.143178  0.932995
#
#                     DeSOx_2nd     前爐SOx濃度       鈣硫比
# 2025-11-06 15:03:01       NaN         NaN       NaN
# 2025-11-06 15:03:31  0.963412  472.081081  7.424292
# 2025-11-06 15:04:01  0.966459  470.145802  7.424292
# 2025-11-06 15:04:31  0.967640  468.586481  7.424292
# 2025-11-06 15:05:01  0.969167  467.732105  7.424292
#
# [5 rows x 100 columns]

# %%
#cfb1.to_excel(f"{datetime.date.today():'%Y%m%d'}-CFB1脫硫劑優化改善.xlsx")  #CFB1 檔案存出

# %%
# 獲取數據 CFB2
cfb2 = async_get_values(
    tag2.keys(),
    timestart=start_time_str,  
    timeend=end_time_str,
    interval='30s'  # 30 秒間隔
)

for c in cfb2:
    cfb2[c] = pd.to_numeric(cfb2[c],errors='coerce')
    
cfb2['前爐SOx濃度'] = cfb2['MLUT4_FIQ-2BTCF']*8/cfb2['MLUT4_FQ-239']*24.5*1000/32.065
cfb2['鈣硫比'] = cfb2['MLUT4_RQ-2BTLS']/cfb2['MLUT4_FIQ-2BTCF']*0.32/0.008
cfb2['DeSOx_1st'] = (cfb2['前爐SOx濃度']-cfb2['MLUT4_AIC-232B'])/cfb2['前爐SOx濃度']
cfb2['DeSOx_2nd'] = (cfb2['MLUT4_AIC-232B']-cfb2['MLUT4_AT-240'])/cfb2['MLUT4_AIC-232B']

cfb2 = cfb2[sorted(cfb2.columns)]
new_index = cfb2.index.to_list()+['datetime']
cfb2 = pd.concat([cfb2,pd.Series(tag2).to_frame().T],axis=0,ignore_index=True)
cfb2.index = new_index
# Out:
# Progress: [██████████████████████████████████████████████████] 93/93 (100%) | Elapsed: 57.3s
# ✅ 完成查詢，耗時 0:01:00.38

# %%
cfb2.head()
# Out:
#                      DeSOx_1st  DeSOx_2nd MLUT4_AIA792101A MLUT4_AIA792101B  \
# 2025-11-06 16:30:32   0.831119   0.911584              4.4         4.233218
# 2025-11-06 16:31:02   0.851595   0.899788              4.4           4.2833
# 2025-11-06 16:31:32   0.862615   0.892067              4.4         4.239239
# 2025-11-06 16:32:02   0.847435   0.902244              4.4          4.23751
# 2025-11-06 16:32:32   0.838425   0.908125         4.401781         4.291561
#
#                     MLUT4_AIC-232B MLUT4_AT-232A MLUT4_AT-237 MLUT4_AT-240  \
# 2025-11-06 16:30:32      69.067333    190.744242     7.749187     6.106689
# 2025-11-06 16:31:02      60.976688    192.320519     7.716285     6.110584
# 2025-11-06 16:31:32      56.650558    193.554162     7.768462     6.114479
# 2025-11-06 16:32:02      62.588295     191.04796     7.746226     6.118374
# 2025-11-06 16:32:32      66.636981    189.440176      7.72788     6.122269
#
#                     MLUT4_FIC-231A MLUT4_FIC-231B  ... MLUT4_TE-951A  \
# 2025-11-06 16:30:32      12.010857       9.622826  ...    131.486946
# 2025-11-06 16:31:02      12.010611       9.622577  ...    131.253223
# 2025-11-06 16:31:32      12.010364       9.622328  ...         131.0
# 2025-11-06 16:32:02      12.010117       9.622079  ...         131.0
# 2025-11-06 16:32:32       12.00987       9.621829  ...         131.0
#
#                     MLUT4_TE-951B MLUT4_TE-953A MLUT4_TE-953B MLUT4_TE-954A  \
# 2025-11-06 16:30:32    139.260516    100.700641         101.0         115.0
# 2025-11-06 16:31:02     139.41945    100.038976    100.928727         115.0
# 2025-11-06 16:31:32    139.846265         100.0    100.257323         115.0
# 2025-11-06 16:32:02    139.204284         100.0         100.0         115.0
# 2025-11-06 16:32:32      139.4794         100.0         100.0         115.0
#
#                     MLUT4_TE-954B MLUT4_ZT-231 MLUT4_ZT-232     前爐SOx濃度  \
# 2025-11-06 16:30:32         115.0    99.894377         10.8  408.971461
# 2025-11-06 16:31:02         115.0    99.896032         10.8  410.881659
# 2025-11-06 16:31:32         115.0    99.897687         10.8  412.349340
# 2025-11-06 16:32:02         115.0    99.899328         10.8  410.238870
# 2025-11-06 16:32:32         115.0    99.899477         10.8  412.420726
#
#                           鈣硫比
# 2025-11-06 16:30:32  4.430155
# 2025-11-06 16:31:02  4.430305
# 2025-11-06 16:31:32  4.430454
# 2025-11-06 16:32:02  4.991956
# 2025-11-06 16:32:32  5.504875
#
# [5 rows x 97 columns]

# %%
#cfb2.to_excel(f"{datetime.date.today():'%Y%m%d'}-CFB2脫硫劑優化改善.xlsx") #CFB2 檔案存出

# %%
import sys
import os

# 取得專案根目錄的路徑 (假設 notebook 在 notebooks/ 內)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# 現在可以正常匯入
from integration_bridge import CFBIntegrationBridge

# 1. 初始化整合橋接器 (CFB1 或 CFB2)
bridge = CFBIntegrationBridge(cfb_unit=2)

# 2. 收集即時數據並執行預測
current_data = bridge.collect_pi_data(realtime=True)
display(current_data)
predictions = bridge.run_online_prediction(current_data)
# 3. 執行持續的即時預測迴圈
bridge.run_realtime_loop(loop_interval=10)  # 每5分鐘
# Out:
# 初始化 OnlinePredictor (v4 - 修正暖機邏輯)...
# 找到初始模型，正在載入: model\xgb_model.json
# 正在初始化持久化的卡爾曼濾波器狀態...
# 初始化 OnlinePredictor (Y2 完整版 v2)...
# 找到初始模型，正在載入: ./model\xgb_model_y2.json
# 🏭 初始化 CFB#2 系統 (Y1 + Y2 預測)
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#    MLUT4_AIA792101A  MLUT4_AIA792101B  MLUT4_AIC-232B  MLUT4_AT-232A  \
# 0               5.7               5.3             2.7            2.4
#
#    MLUT4_AT-237  MLUT4_AT-240  MLUT4_FIC-231A  MLUT4_FIC-231B  MLUT4_FIC-231C  \
# 0           8.8          13.0          14.699          11.795          11.961
#
#    MLUT4_FIC-233  ...  MLUT4_TE-251H  MLUT4_FT-957  MLUT4_FT-956  \
# 0     198.800003  ...          932.0        3000.0        2808.0
#
#    MLUT4_RT-091  MLUT4_PT-231  MLUT4_FT-V004     前爐SOx濃度       鈣硫比  DeSOx_1st  \
# 0           1.7        1392.0            1.8  578.520898  3.608529   0.995333
#
#    DeSOx_2nd
# 0  -3.814815
#
# [1 rows x 39 columns]
# --- [步驟 1] 開始新一輪預測與學習循環 ---
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.8500
# 當前預測值: 0.9956
# 資料緩衝區大小: 1/100
# 🎯 Y1 預測結果: 0.9956
# 🎯 Y2 預測結果: -4.3007
# 🎯 Y3 反推結果: 14.3119
# 🚀 開始 CFB#2 即時預測迴圈 (每 10 秒)
# 按 Ctrl+C 停止...
#
# ==================================================
# ⏰ 2025-11-17 15:34:54
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 2] 開始新一輪預測與學習循環 ---
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.8500
# 當前預測值: 0.9956
# 資料緩衝區大小: 2/100
# 🎯 Y1 預測結果: 0.9956
# 🎯 Y2 預測結果: -4.3007
# 🎯 Y3 反推結果: 14.3119
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:35:05
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 3] 開始新一輪預測與學習循環 ---
# *** 收到第一筆真實數據，觸發熱啟動！拋棄歷史模型和數據。 ***
# 收到上一步真實值 0.9953，更新KF狀態，新平均值: 0.9953
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (0/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 1/100
# ⏳ Y1 模型尚未就緒
# *** 收到第一筆真實數據，觸發熱啟動！ ***
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:35:15
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 4] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9953，更新KF狀態，新平均值: 0.9953
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (1/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 2/100
# ⏳ Y1 模型尚未就緒
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:35:25
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 5] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9952
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (2/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 3/100
# ⏳ Y1 模型尚未就緒
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:35:36
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 6] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9952，更新KF狀態，新平均值: 0.9952
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (3/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 4/100
# ⏳ Y1 模型尚未就緒
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:35:46
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 7] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9951
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (4/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 5/100
# ⏳ Y1 模型尚未就緒
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:35:56
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 8] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9951
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (5/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 6/100
# ⏳ Y1 模型尚未就緒
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:36:07
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 9] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (6/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 7/100
# ⏳ Y1 模型尚未就緒
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:36:17
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 10] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (7/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 8/100
# ⏳ Y1 模型尚未就緒
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:36:27
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 11] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (8/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 9/100
# ⏳ Y1 模型尚未就緒
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:36:38
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 12] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據不足 (9/10)，跳過訓練。
# 模型尚未訓練或正在暖機，無法進行預測。
# 資料緩衝區大小: 10/100
# ⏳ Y1 模型尚未就緒
# ⏳ Y2 模型尚未就緒
# ⏳ Y3 計算尚未就緒
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:36:48
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 13] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 模型不存在或被重置，嘗試進行首次線上訓練...
# 數據量達標(>10)，使用最近 10 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 11/100
# 🎯 Y1 預測結果: 0.9950
# 數據量達標(>10)，使用最近 10 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.4916
# 🎯 Y3 反推結果: 13.0257
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:36:59
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 14] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 12/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.5678
# 🎯 Y3 反推結果: 13.2466
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:37:10
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 15] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 12 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 13/100
# 🎯 Y1 預測結果: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 12 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.5378
# 🎯 Y3 反推結果: 13.1597
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:37:21
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 16] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 14/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.5347
# 🎯 Y3 反推結果: 13.1507
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:37:31
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 17] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 14 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 15/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.5471
# 🎯 Y3 反推結果: 13.1866
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:37:42
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 18] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 16/100
# 🎯 Y1 預測結果: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 15 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.5400
# 🎯 Y3 反推結果: 13.1659
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:37:53
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 19] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 17/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.5094
# 🎯 Y3 反推結果: 13.0774
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:38:03
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 20] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 18/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.5003
# 🎯 Y3 反推結果: 13.0508
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:38:13
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 21] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 19/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.4813
# 🎯 Y3 反推結果: 12.9956
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:38:24
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 22] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 20/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.5232
# 🎯 Y3 反推結果: 13.1173
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:38:34
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 23] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9951，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 21/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.5431
# 🎯 Y3 反推結果: 13.1751
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:38:45
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 24] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 22/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.5378
# 🎯 Y3 反推結果: 13.1595
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:38:55
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 25] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 23/100
# 🎯 Y1 預測結果: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 22 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.4292
# 🎯 Y3 反推結果: 12.8445
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:39:06
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 26] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9951，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 24/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.3838
# 🎯 Y3 反推結果: 12.7129
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:39:16
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 27] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9951，更新KF狀態，新平均值: 0.9951
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9951
# 當前預測值: 0.9950
# 資料緩衝區大小: 25/100
# 🎯 Y1 預測結果: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 24 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.2362
# 🎯 Y3 反推結果: 12.2849
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:39:27
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 28] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9951，更新KF狀態，新平均值: 0.9951
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9951
# 當前預測值: 0.9950
# 資料緩衝區大小: 26/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.2399
# 🎯 Y3 反推結果: 12.2957
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:39:38
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 29] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9951
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9951
# 當前預測值: 0.9950
# 資料緩衝區大小: 27/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.2221
# 🎯 Y3 反推結果: 12.2440
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:39:48
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 30] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 28/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.2384
# 🎯 Y3 反推結果: 12.2913
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:39:58
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 31] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 28 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 29/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.3934
# 🎯 Y3 反推結果: 12.7409
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:40:09
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 32] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 30/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.3893
# 🎯 Y3 反推結果: 12.7290
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:40:19
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 33] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 31/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.4929
# 🎯 Y3 反推結果: 13.0295
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:40:30
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 34] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 31 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 32/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.4624
# 🎯 Y3 反推結果: 12.9410
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:40:40
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 35] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 33/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.4496
# 🎯 Y3 反推結果: 12.9039
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:40:51
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 36] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 34/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.4473
# 🎯 Y3 反推結果: 12.8970
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:41:01
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 37] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 35/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.4415
# 🎯 Y3 反推結果: 12.8803
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:41:12
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 38] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 36/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.4625
# 🎯 Y3 反推結果: 12.9411
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:41:22
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 39] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 37/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.3965
# 🎯 Y3 反推結果: 12.7500
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:41:32
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 40] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 38/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.2411
# 🎯 Y3 反推結果: 12.2992
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:41:42
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 41] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 39/100
# 🎯 Y1 預測結果: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 38 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.4281
# 🎯 Y3 反推結果: 12.8415
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:41:54
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 42] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9950，更新KF狀態，新平均值: 0.9950
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9950
# 當前預測值: 0.9950
# 資料緩衝區大小: 40/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.4178
# 🎯 Y3 反推結果: 13.6950
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:42:04
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 43] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9949
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 40 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9949
# 當前預測值: 0.9950
# 資料緩衝區大小: 41/100
# 🎯 Y1 預測結果: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 40 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.3764
# 🎯 Y3 反推結果: 13.5669
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:42:16
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 44] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9948
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9948
# 當前預測值: 0.9950
# 資料緩衝區大小: 42/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.3090
# 🎯 Y3 反推結果: 13.3579
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:42:26
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 45] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9947，更新KF狀態，新平均值: 0.9947
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9947
# 當前預測值: 0.9950
# 資料緩衝區大小: 43/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.2555
# 🎯 Y3 反推結果: 13.1919
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:42:36
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 46] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9947
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9947
# 當前預測值: 0.9950
# 資料緩衝區大小: 44/100
# 🎯 Y1 預測結果: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 43 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.0999
# 🎯 Y3 反推結果: 12.7097
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:42:47
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 47] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9947
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 44 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9947
# 當前預測值: 0.9950
# 資料緩衝區大小: 45/100
# 🎯 Y1 預測結果: 0.9950
# 🎯 Y2 預測結果: -3.0884
# 🎯 Y3 反推結果: 12.6739
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:42:58
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 48] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9950
# 資料緩衝區大小: 46/100
# 🎯 Y1 預測結果: 0.9950
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 45 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.5807
# 🎯 Y3 反推結果: 11.1001
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:43:09
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 49] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 46 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 47/100
# 🎯 Y1 預測結果: 0.9949
# 🎯 Y2 預測結果: -2.6165
# 🎯 Y3 反推結果: 11.2113
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:43:20
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 50] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 48/100
# 🎯 Y1 預測結果: 0.9949
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 47 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.5473
# 🎯 Y3 反推結果: 10.9967
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:43:31
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 51] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 49/100
# 🎯 Y1 預測結果: 0.9949
# 🎯 Y2 預測結果: -2.5298
# 🎯 Y3 反推結果: 10.9425
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:43:42
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 52] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 50/100
# 🎯 Y1 預測結果: 0.9949
# 🎯 Y2 預測結果: -2.5238
# 🎯 Y3 反推結果: 10.9239
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:43:52
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 53] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 50 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 51/100
# 🎯 Y1 預測結果: 0.9949
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 50 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.2961
# 🎯 Y3 反推結果: 10.2180
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:44:04
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 54] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 52/100
# 🎯 Y1 預測結果: 0.9949
# 🎯 Y2 預測結果: -2.2775
# 🎯 Y3 反推結果: 10.1602
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:44:14
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 55] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9945，更新KF狀態，新平均值: 0.9946
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 52 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 53/100
# 🎯 Y1 預測結果: 0.9949
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 52 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.1401
# 🎯 Y3 反推結果: 9.7343
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:44:26
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 56] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 54/100
# 🎯 Y1 預測結果: 0.9949
# 🎯 Y2 預測結果: -2.1576
# 🎯 Y3 反推結果: 9.7886
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:44:36
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 57] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 55/100
# 🎯 Y1 預測結果: 0.9949
# 🎯 Y2 預測結果: -2.1468
# 🎯 Y3 反推結果: 9.7551
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:44:46
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 58] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 56/100
# 🎯 Y1 預測結果: 0.9949
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 55 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.2647
# 🎯 Y3 反推結果: 10.1207
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:44:58
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 59] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 57/100
# 🎯 Y1 預測結果: 0.9949
# 🎯 Y2 預測結果: -2.1285
# 🎯 Y3 反推結果: 9.6985
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:45:08
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 60] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9949
# 資料緩衝區大小: 58/100
# 🎯 Y1 預測結果: 0.9949
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 57 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.3859
# 🎯 Y3 反推結果: 10.8348
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:45:19
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 61] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9945
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 58 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9948
# 資料緩衝區大小: 59/100
# 🎯 Y1 預測結果: 0.9948
# 🎯 Y2 預測結果: -2.3550
# 🎯 Y3 反推結果: 10.4005
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:45:30
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 62] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9945，更新KF狀態，新平均值: 0.9945
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9948
# 資料緩衝區大小: 60/100
# 🎯 Y1 預測結果: 0.9948
# 🎯 Y2 預測結果: -2.3193
# 🎯 Y3 反推結果: 10.6218
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:45:40
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 63] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9945
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 60 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9948
# 資料緩衝區大小: 61/100
# 🎯 Y1 預測結果: 0.9948
# 🎯 Y2 預測結果: -2.2803
# 🎯 Y3 反推結果: 10.1688
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:45:51
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 64] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9945
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9948
# 資料緩衝區大小: 62/100
# 🎯 Y1 預測結果: 0.9948
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 61 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.3108
# 🎯 Y3 反推結果: 10.2635
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:46:02
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 65] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9945
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 62 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 63/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -2.2386
# 🎯 Y3 反推結果: 10.0397
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:46:13
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 66] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9945
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 64/100
# 🎯 Y1 預測結果: 0.9947
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 63 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.3368
# 🎯 Y3 反推結果: 10.3441
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:46:25
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 67] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 65/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -2.3844
# 🎯 Y3 反推結果: 10.4916
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:46:35
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 68] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 65 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 66/100
# 🎯 Y1 預測結果: 0.9947
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 65 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.8245
# 🎯 Y3 反推結果: 12.2385
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:46:47
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 69] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9945
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 67/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -2.8316
# 🎯 Y3 反推結果: 12.2610
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:46:57
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 70] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9943，更新KF狀態，新平均值: 0.9944
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 67 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9944
# 當前預測值: 0.9947
# 資料緩衝區大小: 68/100
# 🎯 Y1 預測結果: 0.9947
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 67 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.9434
# 🎯 Y3 反推結果: 12.2245
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:47:09
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 71] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9945，更新KF狀態，新平均值: 0.9945
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 69/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.0639
# 🎯 Y3 反推結果: 12.5981
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:47:19
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 72] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9945
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 70/100
# 🎯 Y1 預測結果: 0.9947
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 69 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.2798
# 🎯 Y3 反推結果: 13.2674
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:47:31
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 73] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 71/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.3175
# 🎯 Y3 反推結果: 13.3842
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:47:41
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 74] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 72/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.4115
# 🎯 Y3 反推結果: 13.6756
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:47:51
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 75] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 73/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.4613
# 🎯 Y3 反推結果: 13.8300
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:48:01
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 76] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 74/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.4781
# 🎯 Y3 反推結果: 13.8821
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:48:12
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 77] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9945，更新KF狀態，新平均值: 0.9946
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 74 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 75/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.4287
# 🎯 Y3 反推結果: 13.7290
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:48:22
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 78] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9945，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 76/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.4640
# 🎯 Y3 反推結果: 13.8383
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:48:33
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 79] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 77/100
# 🎯 Y1 預測結果: 0.9947
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 76 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.5904
# 🎯 Y3 反推結果: 14.2302
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:48:44
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 80] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 78/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.5359
# 🎯 Y3 反推結果: 14.0611
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:48:55
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 81] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 79/100
# 🎯 Y1 預測結果: 0.9947
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 78 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -4.1253
# 🎯 Y3 反推結果: 15.8883
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:49:06
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 82] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 80/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.7250
# 🎯 Y3 反推結果: 14.6476
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:49:16
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 83] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9945，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 81/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.6949
# 🎯 Y3 反推結果: 14.5542
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:49:26
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 84] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9945，更新KF狀態，新平均值: 0.9946
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 81 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 82/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.7218
# 🎯 Y3 反推結果: 14.6377
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:49:37
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 85] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 83/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.7554
# 🎯 Y3 反推結果: 14.7419
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:49:48
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 86] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 84/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.9773
# 🎯 Y3 反推結果: 15.4295
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:49:58
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 87] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 85/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.6526
# 🎯 Y3 反推結果: 14.8884
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:50:08
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 88] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9945
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 85 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 86/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.7153
# 🎯 Y3 反推結果: 14.1458
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:50:19
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 89] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9948，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 87/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8949
# 🎯 Y3 反推結果: 14.6847
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:50:29
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 90] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9948，更新KF狀態，新平均值: 0.9947
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9947
# 當前預測值: 0.9947
# 資料緩衝區大小: 88/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8820
# 🎯 Y3 反推結果: 14.6459
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:50:40
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 91] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9948，更新KF狀態，新平均值: 0.9947
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9947
# 當前預測值: 0.9947
# 資料緩衝區大小: 89/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.7341
# 🎯 Y3 反推結果: 14.2024
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:50:50
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 92] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9948，更新KF狀態，新平均值: 0.9947
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9947
# 當前預測值: 0.9947
# 資料緩衝區大小: 90/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.6376
# 🎯 Y3 反推結果: 13.9129
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:51:00
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 93] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9948，更新KF狀態，新平均值: 0.9948
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 90 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9948
# 當前預測值: 0.9947
# 資料緩衝區大小: 91/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.3262
# 🎯 Y3 反推結果: 13.8440
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:51:11
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 94] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9945，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 92/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.2581
# 🎯 Y3 反推結果: 13.2000
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:51:21
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 95] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 93/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.2961
# 🎯 Y3 反推結果: 13.3181
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:51:32
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 96] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 94/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.4118
# 🎯 Y3 反推結果: 13.6767
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:51:42
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 97] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 95/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.5674
# 🎯 Y3 反推結果: 14.1589
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:51:52
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 98] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 96/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8646
# 🎯 Y3 反推結果: 15.0802
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:52:02
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 99] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 97/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8219
# 🎯 Y3 反推結果: 14.9477
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:52:13
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 100] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 98/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8187
# 🎯 Y3 反推結果: 15.4199
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:52:23
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 101] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9945
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 98 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 99/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8218
# 🎯 Y3 反推結果: 15.4297
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:52:34
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 102] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9945
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8680
# 🎯 Y3 反推結果: 15.0908
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:52:44
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 103] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9945
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8672
# 🎯 Y3 反推結果: 15.0883
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:52:54
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 104] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9946，更新KF狀態，新平均值: 0.9946
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9946
# 當前預測值: 0.9947
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8095
# 🎯 Y3 反推結果: 15.3905
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:53:05
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 105] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9945
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9945
# 當前預測值: 0.9947
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9947
# 🎯 Y2 預測結果: -3.8270
# 🎯 Y3 反推結果: 15.9293
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:53:15
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 106] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9942，更新KF狀態，新平均值: 0.9944
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9944
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.8769
# 🎯 Y3 反推結果: 16.0937
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:53:26
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 107] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9942，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.8248
# 🎯 Y3 反推結果: 15.9220
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:53:36
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 108] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9943，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.8419
# 🎯 Y3 反推結果: 15.9782
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:53:47
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 109] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9943，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.7346
# 🎯 Y3 反推結果: 15.6241
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:53:57
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 110] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9943，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.6843
# 🎯 Y3 反推結果: 15.4581
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:54:07
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 111] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -3.2519
# 🎯 Y3 反推結果: 14.0314
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:54:19
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 112] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9943，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.1740
# 🎯 Y3 反推結果: 13.7740
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:54:29
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 113] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9943，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.1495
# 🎯 Y3 反推結果: 13.6932
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:54:39
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 114] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9944
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9944
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.1526
# 🎯 Y3 反推結果: 13.7037
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:54:50
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 115] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9944
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9944
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.1388
# 🎯 Y3 反推結果: 13.6581
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:55:00
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 116] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9944
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9944
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -3.0929
# 🎯 Y3 反推結果: 13.9159
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:55:11
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 117] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9942，更新KF狀態，新平均值: 0.9943
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.9848
# 🎯 Y3 反推結果: 13.5482
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:55:23
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 118] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9942，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -2.9308
# 🎯 Y3 反推結果: 12.9718
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:55:33
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 119] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -2.9046
# 🎯 Y3 反推結果: 13.2756
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:55:43
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 120] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9942，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -2.8220
# 🎯 Y3 反推結果: 12.6128
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:55:55
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 121] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9944，更新KF狀態，新平均值: 0.9943
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9943
# 當前預測值: 0.9946
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9946
# 🎯 Y2 預測結果: -2.9115
# 🎯 Y3 反推結果: 209.6578
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:56:06
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 122] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9088，更新KF狀態，新平均值: 0.9586
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9586
# 當前預測值: 0.9600
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9600
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: -1.7809
# 🎯 Y3 反推結果: 882.6720
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:56:18
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 123] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.4569，更新KF狀態，新平均值: 0.7489
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.7489
# 當前預測值: 0.9600
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9600
# 🎯 Y2 預測結果: -1.8159
# 🎯 Y3 反推結果: 1281.5301
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:56:28
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 124] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.2221，更新KF狀態，新平均值: 0.5288
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.5288
# 當前預測值: 0.5846
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.5846
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: 0.1574
# 🎯 Y3 反推結果: 447.0976
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:56:40
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 125] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.0959，更新KF狀態，新平均值: 0.3479
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.3479
# 當前預測值: 0.5896
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.5896
# 🎯 Y2 預測結果: 0.1030
# 🎯 Y3 反推結果: 499.4498
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:56:51
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 126] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.0460，更新KF狀態，新平均值: 0.2217
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.2217
# 當前預測值: 0.2352
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.2352
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: 0.4989
# 🎯 Y3 反推結果: 288.5551
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:57:03
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 127] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.0111，更新KF狀態，新平均值: 0.1337
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.1337
# 當前預測值: 0.1862
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.1862
# 🎯 Y2 預測結果: 0.7061
# 🎯 Y3 反推結果: 173.9179
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:57:13
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 128] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 -0.0114，更新KF狀態，新平均值: 0.0731
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.0731
# 當前預測值: 0.1873
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.1873
# 🎯 Y2 預測結果: 0.7500
# 🎯 Y3 反推結果: 150.5469
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:57:24
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 129] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 -0.0258，更新KF狀態，新平均值: 0.0317
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.0317
# 當前預測值: 0.1917
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.1917
# 🎯 Y2 預測結果: 0.7274
# 🎯 Y3 反推結果: 165.8225
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:57:34
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 130] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 -0.0321，更新KF狀態，新平均值: 0.0051
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.0051
# 當前預測值: 0.1887
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.1887
# 🎯 Y2 預測結果: 0.5203
# 🎯 Y3 反推結果: 295.8828
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:57:44
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 131] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 -0.0499，更新KF狀態，新平均值: -0.0179
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): -0.0179
# 當前預測值: -0.0061
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: -0.0061
# 🎯 Y2 預測結果: 0.5791
# 🎯 Y3 反推結果: 261.6956
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:57:55
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 132] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 -0.0599，更新KF狀態，新平均值: -0.0354
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): -0.0354
# 當前預測值: -0.0062
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: -0.0062
# 🎯 Y2 預測結果: 0.4385
# 🎯 Y3 反推結果: 351.2037
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 15:58:06
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 133] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 -0.0653，更新KF狀態，新平均值: -0.0479
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): -0.0479
# 當前預測值: -0.0450
# ...
# 當前預測值: 0.9595
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9595
# 🎯 Y2 預測結果: 0.5736
# 🎯 Y3 反推結果: 9.2962
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:52:18
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1116] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9624，更新KF狀態，新平均值: 0.9608
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9608
# 當前預測值: 0.9608
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9608
# 🎯 Y2 預測結果: 0.5786
# 🎯 Y3 反推結果: 8.8905
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:52:29
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1117] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9636，更新KF狀態，新平均值: 0.9620
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9620
# 當前預測值: 0.9617
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9617
# 🎯 Y2 預測結果: 0.5901
# 🎯 Y3 反推結果: 8.4851
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:52:39
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1118] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9642，更新KF狀態，新平均值: 0.9629
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9629
# 當前預測值: 0.9627
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9627
# 🎯 Y2 預測結果: 0.5847
# 🎯 Y3 反推結果: 8.5131
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:52:50
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1119] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9646，更新KF狀態，新平均值: 0.9636
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9636
# 當前預測值: 0.9628
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9628
# 🎯 Y2 預測結果: 0.5858
# 🎯 Y3 反推結果: 8.5316
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:53:00
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1120] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9646，更新KF狀態，新平均值: 0.9640
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9640
# 當前預測值: 0.9628
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9628
# 🎯 Y2 預測結果: 0.5885
# 🎯 Y3 反推結果: 8.6009
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:53:10
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1121] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9641，更新KF狀態，新平均值: 0.9641
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9641
# 當前預測值: 0.9627
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9627
# 🎯 Y2 預測結果: 0.5880
# 🎯 Y3 反推結果: 8.8163
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:53:21
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1122] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9631，更新KF狀態，新平均值: 0.9637
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9637
# 當前預測值: 0.9626
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9626
# 🎯 Y2 預測結果: 0.5797
# 🎯 Y3 反推結果: 8.9950
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:53:31
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1123] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9632，更新KF狀態，新平均值: 0.9634
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9634
# 當前預測值: 0.9628
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9628
# 🎯 Y2 預測結果: 0.5828
# 🎯 Y3 反推結果: 8.8034
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:53:41
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1124] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9638，更新KF狀態，新平均值: 0.9636
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9636
# 當前預測值: 0.9627
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9627
# 🎯 Y2 預測結果: 0.5751
# 🎯 Y3 反推結果: 8.8389
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:53:52
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1125] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9643，更新KF狀態，新平均值: 0.9639
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9639
# 當前預測值: 0.9628
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9628
# 🎯 Y2 預測結果: 0.5778
# 🎯 Y3 反推結果: 8.8237
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:54:02
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1126] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9641，更新KF狀態，新平均值: 0.9640
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9640
# 當前預測值: 0.9628
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9628
# 🎯 Y2 預測結果: 0.5845
# 🎯 Y3 反推結果: 8.5597
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:54:12
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1127] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9645，更新KF狀態，新平均值: 0.9642
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9642
# 當前預測值: 0.9628
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9628
# 🎯 Y2 預測結果: 0.5874
# 🎯 Y3 反推結果: 8.5816
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:54:23
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1128] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9640，更新KF狀態，新平均值: 0.9641
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9641
# 當前預測值: 0.9632
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9632
# 🎯 Y2 預測結果: 0.5836
# 🎯 Y3 反推結果: 8.4110
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:54:33
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1129] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9649，更新KF狀態，新平均值: 0.9645
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9645
# 當前預測值: 0.9632
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9632
# 🎯 Y2 預測結果: 0.5927
# 🎯 Y3 反推結果: 8.1862
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:54:43
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1130] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9651，更新KF狀態，新平均值: 0.9647
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9647
# 當前預測值: 0.9631
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9631
# 🎯 Y2 預測結果: 0.5824
# 🎯 Y3 反推結果: 8.6016
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:54:54
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1131] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9644，更新KF狀態，新平均值: 0.9646
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9646
# 當前預測值: 0.9631
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9631
# 🎯 Y2 預測結果: 0.5795
# 🎯 Y3 反推結果: 8.5788
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:55:04
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1132] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9646，更新KF狀態，新平均值: 0.9646
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9646
# 當前預測值: 0.9631
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9631
# 🎯 Y2 預測結果: 0.5807
# 🎯 Y3 反推結果: 8.5529
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:55:14
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1133] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9646，更新KF狀態，新平均值: 0.9646
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9646
# 當前預測值: 0.9632
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9632
# 🎯 Y2 預測結果: 0.5875
# 🎯 Y3 反推結果: 8.5802
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:55:25
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1134] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9639，更新KF狀態，新平均值: 0.9643
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9643
# 當前預測值: 0.9632
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9632
# 🎯 Y2 預測結果: 0.5916
# 🎯 Y3 反推結果: 8.5363
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:55:35
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1135] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9637，更新KF狀態，新平均值: 0.9641
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9641
# 當前預測值: 0.9631
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9631
# 🎯 Y2 預測結果: 0.5926
# 🎯 Y3 反推結果: 8.5555
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:55:45
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1136] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9635，更新KF狀態，新平均值: 0.9638
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9638
# 當前預測值: 0.9630
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9630
# 🎯 Y2 預測結果: 0.5807
# 🎯 Y3 反推結果: 8.9738
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:55:56
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1137] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9629，更新KF狀態，新平均值: 0.9634
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9634
# 當前預測值: 0.9629
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9629
# 🎯 Y2 預測結果: 0.5825
# 🎯 Y3 反推結果: 8.9351
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:56:06
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1138] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9630，更新KF狀態，新平均值: 0.9633
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9633
# 當前預測值: 0.9630
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9630
# 🎯 Y2 預測結果: 0.5857
# 🎯 Y3 反推結果: 8.8250
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:56:16
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1139] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9633，更新KF狀態，新平均值: 0.9633
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9633
# 當前預測值: 0.9630
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9630
# 🎯 Y2 預測結果: 0.5814
# 🎯 Y3 反推結果: 9.2933
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:56:27
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1140] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9617，更新KF狀態，新平均值: 0.9626
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9626
# 當前預測值: 0.9626
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9626
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: 0.5968
# 🎯 Y3 反推結果: 8.9114
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:56:38
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1141] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9618，更新KF狀態，新平均值: 0.9623
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9623
# 當前預測值: 0.9623
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9623
# 🎯 Y2 預測結果: 0.5947
# 🎯 Y3 反推結果: 8.7149
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:56:48
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1142] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9628，更新KF狀態，新平均值: 0.9625
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9625
# 當前預測值: 0.9624
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9624
# 🎯 Y2 預測結果: 0.5942
# 🎯 Y3 反推結果: 8.9286
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:56:58
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1143] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9620，更新KF狀態，新平均值: 0.9623
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9623
# 當前預測值: 0.9622
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9622
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: 0.5994
# 🎯 Y3 反推結果: 8.6523
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:57:10
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1144] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9628，更新KF狀態，新平均值: 0.9625
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9625
# 當前預測值: 0.9626
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9626
# 🎯 Y2 預測結果: 0.5999
# 🎯 Y3 反推結果: 8.5624
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:57:20
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1145] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9631，更新KF狀態，新平均值: 0.9628
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9628
# 當前預測值: 0.9628
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9628
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: 0.5942
# 🎯 Y3 反推結果: 8.4822
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:57:31
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1146] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9640，更新KF狀態，新平均值: 0.9633
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9633
# 當前預測值: 0.9630
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9630
# 🎯 Y2 預測結果: 0.5918
# 🎯 Y3 反推結果: 8.4097
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:57:41
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1147] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9645，更新KF狀態，新平均值: 0.9638
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9638
# 當前預測值: 0.9631
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9631
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: 0.5898
# 🎯 Y3 反推結果: 8.3682
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:57:52
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1148] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9648，更新KF狀態，新平均值: 0.9642
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9642
# 當前預測值: 0.9631
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9631
# 🎯 Y2 預測結果: 0.5826
# 🎯 Y3 反推結果: 8.3894
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:58:03
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1149] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9654，更新KF狀態，新平均值: 0.9647
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9647
# 當前預測值: 0.9641
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9641
# 🎯 Y2 預測結果: 0.5731
# 🎯 Y3 反推結果: 8.5809
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:58:13
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1150] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9654，更新KF狀態，新平均值: 0.9650
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9650
# 當前預測值: 0.9640
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9640
# 🎯 Y2 預測結果: 0.5705
# 🎯 Y3 反推結果: 8.5036
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:58:24
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1151] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9658，更新KF狀態，新平均值: 0.9653
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9653
# 當前預測值: 0.9644
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9644
# 🎯 Y2 預測結果: 0.5656
# 🎯 Y3 反推結果: 8.6003
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:58:35
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1152] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9658，更新KF狀態，新平均值: 0.9655
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9655
# 當前預測值: 0.9644
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9644
# 🎯 Y2 預測結果: 0.5644
# 🎯 Y3 反推結果: 8.6258
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:58:45
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1153] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9656，更新KF狀態，新平均值: 0.9656
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9656
# 當前預測值: 0.9639
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9639
# 🎯 Y2 預測結果: 0.5644
# 🎯 Y3 反推結果: 8.6240
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:58:55
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1154] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9656，更新KF狀態，新平均值: 0.9656
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9656
# 當前預測值: 0.9648
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9648
# 🎯 Y2 預測結果: 0.5638
# 🎯 Y3 反推結果: 8.7683
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:59:06
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1155] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9650，更新KF狀態，新平均值: 0.9653
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9653
# 當前預測值: 0.9646
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9646
# 🎯 Y2 預測結果: 0.5628
# 🎯 Y3 反推結果: 8.9621
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:59:16
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1156] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9642，更新KF狀態，新平均值: 0.9649
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9649
# 當前預測值: 0.9649
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9649
# 🎯 Y2 預測結果: 0.5651
# 🎯 Y3 反推結果: 9.1759
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:59:27
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1157] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9630，更新KF狀態，新平均值: 0.9641
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9641
# 當前預測值: 0.9646
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9646
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 🎯 Y2 預測結果: 0.5703
# 🎯 Y3 反推結果: 9.3673
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:59:38
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1158] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9619，更新KF狀態，新平均值: 0.9632
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9632
# 當前預測值: 0.9635
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9635
# 🎯 Y2 預測結果: 0.5817
# 🎯 Y3 反推結果: 9.0762
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:59:49
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1159] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9623，更新KF狀態，新平均值: 0.9628
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9628
# 當前預測值: 0.9635
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9635
# 🎯 Y2 預測結果: 0.5809
# 🎯 Y3 反推結果: 9.2626
# 💤 等待 10 秒...
#
# ==================================================
# ⏰ 2025-11-17 18:59:59
# 📡 從 PI Server 收集即時數據...
# ✅ 成功收集 1 筆數據
#
# --- [步驟 1160] 開始新一輪預測與學習循環 ---
# 收到上一步真實值 0.9618，更新KF狀態，新平均值: 0.9624
# *** 誤差超過門檻，觸發模型再訓練！ ***
# 數據量達標(>10)，使用最近 100 筆資料進行模型訓練...
# 模型訓練完成！已更新模型。
# 新模型已儲存至: model\xgb_model.json
# 開始為當前資料進行預測...
# 使用的 prev_target (來自持久化KF): 0.9624
# 當前預測值: 0.9628
# 資料緩衝區大小: 100/100
# 🎯 Y1 預測結果: 0.9628
# 🎯 Y2 預測結果: 0.5879
# 🎯 Y3 反推結果: 9.3126
# 💤 等待 10 秒...
#
# 🛑 使用者中斷，正在生成最終報告...
# 📊 正在生成整合系統報告...
#
# 正在生成使用報告至 usage_report.html...
# 報告已成功儲存至: usage_report.html
#
# 正在生成 Y2/Y3 使用報告至 ./usage_report_y2.html...
# 報告已成功儲存至: ./usage_report_y2.html
# 📁 整合歷史已儲存至: CFB2_integration_history_20251117.csv
# ✅ 整合報告生成完成
